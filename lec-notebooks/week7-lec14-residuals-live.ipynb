# %%
# HIDDEN
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Regression line vs other lines

# %%
def standard_units(arr):
    """ Converts an array to standard units """
    return (arr - np.average(arr))/np.std(arr)

def correlation(t, x, y):
    """ Computes correlation: t is a table, and x and y are column names """
    x_standard = standard_units(t.column(x))
    y_standard = standard_units(t.column(y))
    return np.average(x_standard * y_standard)

def slope(t, x, y):
    """ Computes the slope of the regression line, like correlation above """
    r = correlation(t, x, y)
    y_sd = np.std(t.column(y))
    x_sd = np.std(t.column(x))
    return r * y_sd / x_sd

def intercept(t, x, y):
    """ Computes the intercept of the regression line, like slope above """
    x_mean = np.mean(t.column(x))
    y_mean = np.mean(t.column(y))
    return y_mean - slope(t, x, y)*x_mean

def fitted_values(t, x, y):
    """Return an array of the regression estimates (predictions) at all the x values"""
    a = slope(t, x, y)
    b = intercept(t, x, y)
    return a*t.column(x) + b # y value (regression line)

# %%
def demographics_errors(slope, intercept):
    # Use four convenient points from the original data
    sample = [[14.7, 33995], [19.1, 61454], [50.7, 71183], [59.5, 105918]]
    demographics.scatter('College%', 'Median Income', alpha=0.5)
    xlims = make_array(5, 75)
    # Plot a line with the slope and intercept you specified:
    plots.plot(xlims, slope * xlims + intercept, lw=4)
    # Plot red lines from each of the four points to the line
    for x, y in sample:
        plots.plot([x, x], [y, slope * x + intercept], color='r', lw=4)

# %%
demographics = Table.read_table('data/district_demographics2016.csv')
demographics = demographics.drop(
    'State', 'District', 'Percent voting for Clinton')
demographics.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Median Income</th> <th>College%</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>47083        </td> <td>24      </td>
#         </tr>
#         <tr>
#             <td>42035        </td> <td>21.8    </td>
#         </tr>
#         <tr>
#             <td>46544        </td> <td>22.8    </td>
#         </tr>
#         <tr>
#             <td>41110        </td> <td>17      </td>
#         </tr>
#         <tr>
#             <td>51690        </td> <td>30.3    </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (430 rows omitted)</p>

# %%
demographics.scatter('College%', 'Median Income')

# %%
correlation(demographics, 'College%', 'Median Income')
# Out:
# 0.8184648517141335

# %%
regression_slope = slope(demographics, 'College%', 'Median Income')
regression_intercept = intercept(demographics, 'College%', 'Median Income')
regression_slope, regression_intercept
# Out:
# (1270.70168946388, 20802.577766677925)

# %%
predicted = fitted_values(demographics, 'College%', 'Median Income')

# %%
demographics = demographics.with_column(
    'Linear Prediction', predicted)
demographics.scatter('College%')

# %%
predicted
# Out:
# array([ 51299.41831381,  48503.87459699,  49774.57628645,  42404.50648756,
#         59304.83895743,  67437.32977   ,  45454.19054228,  58415.34777481,
#         51934.76915854,  64006.43520845,  41769.15564283,  45200.05020438,
#         66547.83858738,  78492.43446834,  38592.40141917,  58161.20743692,
#         68453.89112157,  41769.15564283,  58923.62845059,  54984.45321326,
#         40879.66446021,  50918.20780697,  41896.22581178,  76205.1714273 ,
#         96409.32828978,  80779.69750937,  81160.90801621,  77984.15379255,
#         36305.13837814,  93232.57406612,  98950.73166871,  65912.48774265,
#         72647.2066968 ,  56255.15490272,  30841.12111344,  51426.48848276,
#         47233.17290753,  64006.43520845,  56128.08473377,  64133.5053774 ,
#         72265.99618997,  79508.99581991,  45200.05020438,  52697.19017222,
#         74680.32939995,  49647.50611751,  47995.5939212 , 103906.46825762,
#         53078.40067906,  41260.87496705,  46979.03256963,  67691.4701079 ,
#         50664.06746908,  73663.76804838,  63116.94402583,  33255.45432342,
#         44056.41868387,  52570.12000327,  54476.17253747,  36432.20854708,
#         91961.87237666,  44564.69935965,  61465.03182952,  77475.87311677,
#         76713.45210309,  60448.47047795,  56636.36540956,  38719.47158812,
#         93740.8547419 ,  68835.10162841,  55746.87422693,  62608.66335004,
#         42531.57665651,  45072.98003544,  81287.97818516,  89801.67950457,
#         57907.06709902,  65150.06672897,  67818.54027684,  73917.90838627,
#         62100.38267425,  67564.39993895,  65404.20706686,  66801.97892527,
#         82812.82021252,  66929.04909422,  60194.33014006,  56255.15490272,
#         59304.83895743,  46979.03256963,  54984.45321326,  56128.08473377,
#         65658.34740475,  53586.68135485,  59813.11963322,  47868.52375226,
#         59558.97929533,  61846.24233636,  50536.99730013,  45835.40104912,
#         64387.64571529,  68962.17179736,  69851.66297998,  45454.19054228,
#         49647.50611751,  55365.6637201 ,  68453.89112157,  53713.75152379,
#         70614.08399366,  47995.5939212 ,  51172.34814486,  68835.10162841,
#         57652.92676113,  52061.83932749,  52570.12000327,  54730.31287536,
#         72901.3470347 ,  47360.24307647,  58415.34777481,  43802.27834597,
#         43166.92750124,  54476.17253747,  58669.4881127 ,  74172.04872416,
#         97807.10014819,  71122.36466945,  48503.87459699,  48249.7342591 ,
#         66547.83858738,  56128.08473377,  53078.40067906,  59050.69861954,
#         57525.85659218,  76840.52227204,  66547.83858738,  51299.41831381,
#         59177.76878849,  74299.11889311,  46470.75189385,  49012.15527278,
#         44564.69935965,  61083.82132268,  50409.92713119,  54984.45321326,
#         51934.76915854,  90309.96018035,  87133.20595669,  72520.13652786,
#         62227.4528432 ,  88403.90764616,  49520.43594856,  47233.17290753,
#         49901.6464554 ,  53840.82169274,  77984.15379255,  47106.10273858,
#         50664.06746908,  47868.52375226,  54222.03219958,  55238.59355115,
#         57017.5759164 ,  62862.80368793,  52188.90949644,  51172.34814486,
#         57907.06709902,  81033.83784727,  58288.27760586,  40752.59429126,
#         47360.24307647,  60067.25997111,  56763.43557851,  36559.27871603,
#         61083.82132268,  59304.83895743,  50536.99730013,  47487.31324542,
#         46089.54138701,  42150.36614967,  56255.15490272,  67691.4701079 ,
#         50028.71662435,  59686.04946427,  63244.01419477,  80779.69750937,
#         64006.43520845,  63625.22470161,  73536.69787943,  68835.10162841,
#         91453.59170087,  58542.41794376,  69597.52264209,  68326.82095263,
#         85608.36392934,  93740.8547419 ,  76713.45210309,  75315.68024468,
#         80271.41683359,  66420.76841843,  52061.83932749,  50028.71662435,
#         80017.27649569,  64006.43520845,  39481.8926018 ,  59940.18980217,
#         51045.27797592,  60702.61081584,  48630.94476594,  44945.90986649,
#         56382.22507167,  52061.83932749,  72393.06635891,  59304.83895743,
#         56382.22507167,  69724.59281104,  83066.96055041,  74426.18906205,
#         77348.80294782,  58288.27760586,  48503.87459699,  50028.71662435,
#         47106.10273858,  45327.12037333,  53713.75152379,  47614.38341437,
#         61210.89149163,  83321.1008883 ,  54349.10236852,  51172.34814486,
#         56636.36540956,  57144.64608534,  50282.85696224,  39863.10310864,
#         60194.33014006,  62100.38267425,  70614.08399366,  49012.15527278,
#         40117.24344653,  53205.47084801,  60829.68098479,  46724.89223174,
#         68072.68061473,  66420.76841843,  59431.90912638,  56763.43557851,
#         89928.74967351,  78619.50463728,  53586.68135485,  63879.3650395 ,
#         71122.36466945,  81415.04835411,  70232.87348682,  85989.57443617,
#         62862.80368793,  63498.15453266,  62608.66335004,  47487.31324542,
#         55365.6637201 ,  64133.5053774 ,  97425.88964135,  64514.71588424,
#        112547.23974597,  60194.33014006,  53332.54101695,  36559.27871603,
#         72393.06635891,  77348.80294782,  66166.62808054,  57907.06709902,
#         60448.47047795,  69978.73314893,  50282.85696224,  53840.82169274,
#         53967.89186169,  59304.83895743,  68199.75078368,  59940.18980217,
#         59813.11963322,  86370.78494301,  74807.39956889,  53205.47084801,
#         66420.76841843,  63625.22470161,  63625.22470161,  68453.89112157,
#         56001.01456483,  52061.83932749,  51299.41831381,  71376.50500734,
#         55111.5233822 ,  66801.97892527,  49774.57628645,  90055.81984246,
#         54222.03219958,  52061.83932749,  52443.04983433,  54476.17253747,
#         63752.29487056,  58415.34777481,  63752.29487056,  56255.15490272,
#         54857.38304431,  72901.3470347 ,  50918.20780697,  64133.5053774 ,
#         60702.61081584,  63116.94402583,  61846.24233636,  56128.08473377,
#         43548.13800808,  54094.96203063,  41006.73462915,  47360.24307647,
#         51045.27797592,  48249.7342591 ,  59177.76878849,  42404.50648756,
#         49901.6464554 ,  53205.47084801,  59050.69861954,  73028.41720364,
#         51045.27797592,  73155.48737259,  54730.31287536,  58923.62845059,
#         55619.80405799,  49393.36577962,  52697.19017222,  63625.22470161,
#         65785.4175737 ,  65785.4175737 ,  57907.06709902,  52697.19017222,
#         49647.50611751,  67183.18943211,  67437.32977   ,  54476.17253747,
#         54730.31287536,  52697.19017222,  75696.89075152,  75951.03108941,
#         71249.43483839,  44437.62919071,  64260.57554634,  64006.43520845,
#         71503.57517629,  63371.08436372,  48758.01493488,  59813.11963322,
#         50028.71662435,  45708.33088017,  46343.6817249 ,  57525.85659218,
#         45454.19054228,  60194.33014006,  49647.50611751,  49520.43594856,
#         68453.89112157,  48630.94476594,  56509.29524061,  55873.94439588,
#         51426.48848276,  47360.24307647,  69978.73314893,  46724.89223174,
#         58796.55828165,  46724.89223174,  49647.50611751,  45962.47121806,
#         51172.34814486,  58161.20743692,  49266.29561067,  49266.29561067,
#         72647.2066968 ,  52188.90949644,  78111.2239615 ,  78111.2239615 ,
#         48376.80442804,  77602.94328571,  68072.68061473,  76967.59244098,
#         46597.82206279,  43293.99767019,  34017.8753371 ,  88785.118153  ,
#         46851.96240069,  64387.64571529,  75951.03108941,  32620.10347869,
#         39990.17327758,  46724.89223174,  45454.19054228,  48885.08510383,
#         47614.38341437,  57271.71625429,  85227.1534225 ,  59177.76878849,
#         51045.27797592,  57525.85659218,  62100.38267425,  73663.76804838,
#         56636.36540956,  67056.11926316,  68453.89112157,  89801.67950457,
#         91326.52153192,  64514.71588424,  54094.96203063,  59050.69861954,
#         56255.15490272,  54603.24270642,  70359.94365577,  99331.94217555,
#         46724.89223174,  75951.03108941,  57271.71625429,  59304.83895743,
#         53078.40067906,  46343.6817249 ,  59431.90912638,  58542.41794376,
#         98315.38082397,  64641.78605318,  73917.90838627,  50664.06746908,
#         48122.66409015,  42912.78716335,  56636.36540956,  74934.46973784,
#         53078.40067906,  55619.80405799,  67691.4701079 ,  54349.10236852,
#         50155.78679329,  53078.40067906,  55238.59355115])

# %%
actual = demographics.column('Median Income')
errors = actual - predicted

# %%
demographics.with_column('Error', errors)
# Out:
# Median Income | College% | Linear Prediction | Error
# 47083         | 24       | 51299.4           | -4216.42
# 42035         | 21.8     | 48503.9           | -6468.87
# 46544         | 22.8     | 49774.6           | -3230.58
# 41110         | 17       | 42404.5           | -1294.51
# 51690         | 30.3     | 59304.8           | -7614.84
# 61413         | 36.7     | 67437.3           | -6024.33
# 34664         | 19.4     | 45454.2           | -10790.2
# 76440         | 29.6     | 58415.3           | 18024.7
# 50537         | 24.5     | 51934.8           | -1397.77
# 49072         | 34       | 64006.4           | -14934.4
# ... (425 rows omitted)

# %%
np.mean(errors)
# 0.000000000000635 
# ~0
# Out:
# 6.356008950321154e-13

# %%
np.mean(errors ** 2) ** 0.5
# Out:
# 9398.515588571281

# %%
demographics_errors(regression_slope, regression_intercept)

# %%
# takes any slope, any intercept

demographics_errors(1500, 20000)

# %%
demographics_errors(-1000, 75000)

# %% [markdown]
# ### Root Mean Square Error ###

# %%
def show_demographics_rmse(slope, intercept):
    demographics_errors(slope, intercept)
    x = demographics.column('College%')
    y = demographics.column('Median Income')
    prediction = slope * x + intercept
    mse = np.mean((y - prediction) ** 2)
    print("Root mean squared error:", round(mse ** 0.5, 2))

# %%
show_demographics_rmse(-1000, 75000)
# Out:
# Root mean squared error: 30247.88

# %%
show_demographics_rmse(1500, 20000)
# Out:
# Root mean squared error: 11559.09

# %%
show_demographics_rmse(regression_slope, regression_intercept)
# Out:
# Root mean squared error: 9398.52

# %% [markdown]
# ### Numerical Optimization ###

# %%
x = np.arange(1, 3, 0.1)
y = (x-2)**2 + 3
Table().with_columns('x', x, 'y', y).plot('x')

# %%
def f(x):
    return ((x-2)**2) + 3

# %%
minimize(f)
# Out:
# 1.9999999946252267

# %%
def complicated_function(x):
    return 2 * np.sin(x*np.pi) + x ** 3 + x ** 4

# %%
x = np.arange(-1.5, 1.5, 0.05)
y2 = complicated_function(x)
Table().with_columns('x', x, 'y', y2).plot('x')

# %%
minimize(complicated_function)
# Out:
# -0.5126437620940081

# %% [markdown]
# ### Minimizing RMSE ###

# %%
def demographics_rmse(any_slope, any_intercept):
    x = demographics.column('College%')
    y = demographics.column('Median Income')
    estimate = any_slope*x + any_intercept
    return (np.mean((y - estimate) ** 2)) ** 0.5

# %%
demographics_rmse(1500, 20000)
# Out:
# 11559.086490075999

# %%
demographics_rmse(-1000, 75000)
# Out:
# 30247.883767944502

# %%
minimize(demographics_rmse)
# Out:
# array([ 1270.70168805, 20802.57933807])

# %%
make_array(regression_slope, regression_intercept)
# Out:
# array([ 1270.70168946, 20802.57776668])

# %% [markdown]
# ### Nonlinear Regression ###

# %%
shotput = Table.read_table('data/shotput.csv')
shotput
# Out:
# Weight Lifted | Shot Put Distance
# 37.5          | 6.4
# 51.5          | 10.2
# 61.3          | 12.4
# 61.3          | 13
# 63.6          | 13.2
# 66.1          | 13
# 70            | 12.7
# 92.7          | 13.9
# 90.5          | 15.5
# 90.5          | 15.8
# ... (18 rows omitted)

# %%
shotput.scatter('Weight Lifted')

# %%
def shotput_linear_rmse(any_slope, any_intercept):
    x = shotput.column('Weight Lifted')
    y = shotput.column('Shot Put Distance')
    estimate = any_slope*x + any_intercept
    return np.mean((y - estimate) ** 2) ** 0.5

# %%
best_line = minimize(shotput_linear_rmse)
best_line
# Out:
# array([0.09834382, 5.95962883])

# %%
shotput_linear_rmse(0.09834382, 5.95962883)
# Out:
# 1.219444484505928

# %%
weights = shotput.column(0)

# %%
linear_fit = best_line.item(0)*weights + best_line.item(1)

shotput.with_column(
    'Best Line', linear_fit
).scatter(0)

# %%
correlation(shotput, 'Shot Put Distance', 'Weight Lifted')
# Out:
# 0.8929919094772174

# %% [markdown]
# **Quadratic Function**
#
# $$
# f(x) ~=~ ax^2 + bx + c
# $$
# for constants $a$, $b$, and $c$.

# %%
def shotput_quadratic_rmse(a, b, c):
    x = shotput.column('Weight Lifted')
    y = shotput.column('Shot Put Distance')
    estimate = a*(x**2) + b*x + c
    return np.mean((y - estimate) ** 2) ** 0.5

# %%
best_quad = minimize(shotput_quadratic_rmse)
best_quad
# Out:
# array([-1.04003731e-03,  2.82706003e-01, -1.53167618e+00])

# %%
shotput_quadratic_rmse(-1.04003731e-03,  2.82706003e-01, -1.53167618e+00)
# Out:
# 0.9818845230610078

# %%
# x = weight lifted = 100 kg
# Then predicted shot put distance:

(-0.00104)*(100**2) + 0.2827*100 - 1.5318
# Out:
# 16.3382

# %%
quad_fit = best_quad.item(0)*(weights**2) + best_quad.item(1)*weights + best_quad.item(2)

# %%
shotput.with_column('Best Quadratic Curve', quad_fit).scatter(0)

# %% [markdown]
# ## Residuals

# %%
def residuals(t, x, y):
    predictions = fitted_values(t, x, y)
    return t.column(y) - predictions

# %%
demographics = demographics.with_columns(
    'Fitted Value', fitted_values(demographics, 'College%', 'Median Income'),
    'Residual', residuals(demographics, 'College%', 'Median Income')
)
demographics
# Out:
# Median Income | College% | Linear Prediction | Fitted Value | Residual
# 47083         | 24       | 51299.4           | 51299.4      | -4216.42
# 42035         | 21.8     | 48503.9           | 48503.9      | -6468.87
# 46544         | 22.8     | 49774.6           | 49774.6      | -3230.58
# 41110         | 17       | 42404.5           | 42404.5      | -1294.51
# 51690         | 30.3     | 59304.8           | 59304.8      | -7614.84
# 61413         | 36.7     | 67437.3           | 67437.3      | -6024.33
# 34664         | 19.4     | 45454.2           | 45454.2      | -10790.2
# 76440         | 29.6     | 58415.3           | 58415.3      | 18024.7
# 50537         | 24.5     | 51934.8           | 51934.8      | -1397.77
# 49072         | 34       | 64006.4           | 64006.4      | -14934.4
# ... (425 rows omitted)

# %%
demographics.scatter('College%')

# %%
def plot_residuals(t, x, y):
    tbl = t.with_columns(
        'Fitted', fitted_values(t, x, y),
        'Residual', residuals(t, x, y)
    )
    tbl.select(x, y, 'Fitted').scatter(0)
    tbl.scatter(x, 'Residual')

# %%
plot_residuals(demographics, 'College%', 'Median Income')

# %%
# when we look at residuals, we are looking patterns in
# our errors

# above, there is no discernible pattern, negative/positive trend
# centered at 0

# this is what we want to see in our residual plot

# %%
galton = Table.read_table('data/galton.csv')

heights = Table().with_columns(
    'MidParent', galton.column('midparentHeight'),
    'Child', galton.column('childHeight')
    )
plot_residuals(heights, 'MidParent', 'Child')

# %%
# check residual plot above
# are there any discernible patterns or trends?

# what does this mean about our regression line we generated above for our galton data?
# our regression line, our predictions for child height based on midparent height
# are pretty good!

# %% [markdown]
# ## Dugongs ##

# %%
dugong = Table.read_table('data/dugong.csv')
dugong.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Length</th> <th>Age</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1.8   </td> <td>1   </td>
#         </tr>
#         <tr>
#             <td>1.85  </td> <td>1.5 </td>
#         </tr>
#         <tr>
#             <td>1.87  </td> <td>1.5 </td>
#         </tr>
#         <tr>
#             <td>1.77  </td> <td>1.5 </td>
#         </tr>
#         <tr>
#             <td>2.02  </td> <td>2.5 </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (22 rows omitted)</p>

# %%
dugong.scatter('Length', 'Age')

# %%
correlation(dugong, 'Length', 'Age')
# Out:
# 0.8296474554905714

# %%
plot_residuals(dugong, 'Length', 'Age')

# %%
# what does our residual plot look like?
# do you see any discernible pattern or trend?

# what does this residual plot say about our regression line for dugongs?

# %%
# maybe a linear regression line is not the best fit 
# for our dugong data set

# would a nonlinear regression help us make better predictions?

# %%
# take home CHALLENGE
# try a nonlinear regression to predict dugong ages based on length
# visual confirmation of how good your prediction(s) is
# hint: shotput example


# triple bonus: compare rmse of the linear regression and the rmse of the nonlinear 
#regression line
# quantitative measure of how good your predictions are

# %% [markdown]
# # US Women

# %%
us_women = Table.read_table('data/us_women.csv')
us_women.show(5)

# %%
correlation(us_women, 'height', 'ave weight')

# %%
plot_residuals(us_women, 'height', 'ave weight')

# %% [markdown]
# ## Average of Residuals ##

# %%
residuals(dugong, 'Length', 'Age')
# Out:
# array([ 2.777806  ,  2.08922205,  1.61378847,  3.99095637, -0.95196339,
#        -5.39488314, -1.54228166, -4.15716635, -4.29661747, -6.14921895,
#         1.00685118, -0.15716635, -2.98520142, -2.74748463, -2.72291821,
#        -2.86236932,  1.4165329 , -0.19835179, -1.14921895, -1.78867006,
#        -2.92812118,  1.35078105, -1.69040439,  0.71132994,  2.88329487,
#         8.90786129, 14.97361315])

# %%
round(np.average(residuals(dugong, 'Length', 'Age')), 6)
# Out:
# 0.0

# %%
round(np.average(residuals(heights, 'MidParent', 'Child')), 6)
# Out:
# 0.0

# %%
round(np.average(residuals(demographics, 'College%', 'Median Income')), 6)
# Out:
# 0.0

# %%
heights = heights.with_columns(
    'Residual', residuals(heights, 'MidParent', 'Child'),
    'Fitted Value', fitted_values(heights, 'MidParent', 'Child')
)
heights
# Out:
# MidParent | Child | Residual  | Fitted Value
# 75.43     | 73.2  | 2.48763   | 70.7124
# 75.43     | 69.2  | -1.51237  | 70.7124
# 75.43     | 69    | -1.71237  | 70.7124
# 75.43     | 69    | -1.71237  | 70.7124
# 73.66     | 73.5  | 3.91576   | 69.5842
# 73.66     | 72.5  | 2.91576   | 69.5842
# 73.66     | 65.5  | -4.08424  | 69.5842
# 73.66     | 65.5  | -4.08424  | 69.5842
# 72.06     | 71    | 2.43553   | 68.5645
# 72.06     | 68    | -0.564467 | 68.5645
# ... (924 rows omitted)

# %%
round(correlation(heights, 'MidParent', 'Residual'), 6)
# Out:
# -0.0

# %%
round(correlation(heights, 'Fitted Value', 'Residual'), 6)
# Out:
# -0.0

# %% [markdown]
# ## A Measure of Clustering ##

# %%
def plot_fitted(t, x, y):
    tbl = t.select(x, y)
    tbl.with_columns('Fitted Value', fitted_values(t, x, y)).scatter(0)

# %%
plot_fitted(heights, 'MidParent', 'Child')

# %%
child_predictions_sd = np.std(fitted_values(heights, 'MidParent', 'Child'))
child_observed_sd = np.std(heights.column('Child'))
print(child_predictions_sd)
print(child_observed_sd)
# Out:
# 1.148145168378806
# 3.5773346010057634

# %%
child_predictions_sd / child_observed_sd
# Out:
# 0.32094989606395957

# %%
correlation(heights, 'MidParent', 'Child')
# Out:
# 0.32094989606395924

# %%
correlation(dugong, 'Length', 'Age')
# Out:
# 0.8296474554905714

# %%
dugong_prediction_sd = np.std(fitted_values(dugong, 'Length', 'Age'))
dugong_observed_sd = np.std(dugong.column(1))
dugong_prediction_sd / dugong_observed_sd
# Out:
# 0.8296474554905713

# %%
hybrid = Table.read_table('data/hybrid.csv')
hybrid.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>vehicle</th> <th>year</th> <th>msrp</th> <th>acceleration</th> <th>mpg</th> <th>class</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Prius (1st Gen)</td> <td>1997</td> <td>24509.7</td> <td>7.46        </td> <td>41.26</td> <td>Compact   </td>
#         </tr>
#         <tr>
#             <td>Tino           </td> <td>2000</td> <td>35355  </td> <td>8.2         </td> <td>54.1 </td> <td>Compact   </td>
#         </tr>
#         <tr>
#             <td>Prius (2nd Gen)</td> <td>2000</td> <td>26832.2</td> <td>7.97        </td> <td>45.23</td> <td>Compact   </td>
#         </tr>
#         <tr>
#             <td>Insight        </td> <td>2000</td> <td>18936.4</td> <td>9.52        </td> <td>53   </td> <td>Two Seater</td>
#         </tr>
#         <tr>
#             <td>Civic (1st Gen)</td> <td>2001</td> <td>25833.4</td> <td>7.04        </td> <td>47.04</td> <td>Compact   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (148 rows omitted)</p>

# %%
plot_residuals(hybrid, 'acceleration', 'mpg')

# %%
correlation(hybrid, 'acceleration', 'mpg')
# Out:
# -0.5060703843771186

# %%
np.std(fitted_values(hybrid, 'acceleration', 'mpg'))/np.std(hybrid.column('mpg'))
# Out:
# 0.5060703843771186

# %% [markdown]
# No matter what the shape of the scatter plot, the SD of the fitted values is a fraction of the SD of the observed values of $y$. The fraction is |r|.
#
# $$
# \frac{\mbox{SD of fitted values}}{\mbox{SD of }y} ~=~ |r| ~~~~~~~~~~ \mbox{That is,} ~~ \mbox{SD of fitted values} = |r|\cdot \mbox{SD of }y
# $$

# %% [markdown]
# ## SD of the Residuals ##
# No matter what the shape of the scatter plot, the SD of the residuals is a fraction of the SD of the observed values of $y$. The fraction is  $\sqrt{1-r^2}$.
#
# $$
# \mbox{SD of residuals} ~=~ \sqrt{1 - r^2} \cdot \mbox{SD of }y
# $$

# %%
plot_fitted(heights, 'MidParent', 'Child')

# %%
plot_fitted(heights, 'MidParent', 'Child')
ave_child = np.mean(heights.column('Child'))
plots.plot([64, 76], [ave_child, ave_child]);

# %%
np.std(heights.column('Child')) ** 2

# %%
np.std(residuals(heights, 'MidParent', 'Child')) ** 2

# %%
np.std(heights.column('Fitted Value')) ** 2

# %%
np.std(dugong.column('Age')) ** 2

# %%
np.std(fitted_values(dugong, 'Length', 'Age')) ** 2

# %%
np.std(residuals(dugong, 'Length', 'Age')) ** 2

# %%
r = correlation(heights, 'MidParent', 'Child')
r

# %%
np.sqrt(1 - r**2) * np.std(heights.column('Child'))

# %%
np.std(residuals(hybrid, 'acceleration', 'mpg'))

# %%
r = correlation(hybrid, 'acceleration', 'mpg')
r

# %%
np.sqrt(1 - r**2)*np.std(hybrid.column('mpg'))
